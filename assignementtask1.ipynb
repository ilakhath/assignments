# %%
import pandas as pd

# %%
df=pd.read_excel(r"D:\data1.xlsx",sheet_name="Jan")

# %%
df
# Out:
#     Day    Product   Sales
# 0     1      cloths     20
# 1     2      cloths     30
# 2     3      cloths      4
# 3     4      cloths     50
# 4     5      cloths     32
# 5     6      cloths     60
# 6     7      cloths     45
# 7     8      cloths     32
# 8     9      cloths     12
# 9    10      cloths     23
# 10   11      cloths     56
# 11   12      cloths     78
# 12   13    Footware     45
# 13   14    Footware     76
# 14   15    Footware      2
# 15   16    Footware     32
# 16   17    Footware     45
# 17   18    Footware     67
# 18   19    Footware     89
# 19   20    Footware     32
# 20   21    Footware      4
# 21   22    Footware      6
# 22   23    Footware      8
# 23   24  Electronic     98
# 24   25  Electronic     76
# 25   26  Electronic     45
# 26   27  Electronic     32
# 27   28  Electronic     43
# 28   29  Electronic     21
# 29   30  Electronic     12

# %%
df.shape
# Out:
# (30, 3)

# %%
df.head()
# Out:
#    Day Product   Sales
# 0    1   cloths     20
# 1    2   cloths     30
# 2    3   cloths      4
# 3    4   cloths     50
# 4    5   cloths     32

# %%
df.tail()
# Out:
#     Day    Product   Sales
# 25   26  Electronic     45
# 26   27  Electronic     32
# 27   28  Electronic     43
# 28   29  Electronic     21
# 29   30  Electronic     12

# %%
df.dtypes
# Out:
# Day          int64
# Product     object
# Sales        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Day', 'Product ', 'Sales'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Day       30 non-null     int64
#  1   Product   30 non-null     object
#  2   Sales     30 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 848.0+ bytes

# %%
#Filter only cloths data and display

# %%
df_clo=df[df["Product "]=="cloths"]

# %%
df_clo
# Out:
#     Day Product   Sales
# 0     1   cloths     20
# 1     2   cloths     30
# 2     3   cloths      4
# 3     4   cloths     50
# 4     5   cloths     32
# 5     6   cloths     60
# 6     7   cloths     45
# 7     8   cloths     32
# 8     9   cloths     12
# 9    10   cloths     23
# 10   11   cloths     56
# 11   12   cloths     78

# %%
df['Product '].unique()
# Out:
# array(['cloths', 'Footware', 'Electronic'], dtype=object)

# %%
#Filter only electronic data and display

# %%
df_ele=df[df['Product ']=='Electronic']

# %%
df_ele
# Out:
#     Day    Product   Sales
# 23   24  Electronic     98
# 24   25  Electronic     76
# 25   26  Electronic     45
# 26   27  Electronic     32
# 27   28  Electronic     43
# 28   29  Electronic     21
# 29   30  Electronic     12

# %%
#		c> Filter only Foot ware data and display

# %%
df_foot=df[df['Product ']=="Footware"]

# %%
df_foot
# Out:
#     Day  Product   Sales
# 12   13  Footware     45
# 13   14  Footware     76
# 14   15  Footware      2
# 15   16  Footware     32
# 16   17  Footware     45
# 17   18  Footware     67
# 18   19  Footware     89
# 19   20  Footware     32
# 20   21  Footware      4
# 21   22  Footware      6
# 22   23  Footware      8

# %%
#		e> Filter cloths and electronic data & display

# %%
list=["cloths","Electronic"]

# %%
df_cl_ele=df[df["Product "].isin(list)]

# %%
df_cl_ele
# Out:
#     Day    Product   Sales
# 0     1      cloths     20
# 1     2      cloths     30
# 2     3      cloths      4
# 3     4      cloths     50
# 4     5      cloths     32
# 5     6      cloths     60
# 6     7      cloths     45
# 7     8      cloths     32
# 8     9      cloths     12
# 9    10      cloths     23
# 10   11      cloths     56
# 11   12      cloths     78
# 23   24  Electronic     98
# 24   25  Electronic     76
# 25   26  Electronic     45
# 26   27  Electronic     32
# 27   28  Electronic     43
# 28   29  Electronic     21
# 29   30  Electronic     12

# %%
#Task4: import excel "Jan" and "Feb"  sheets
#Append two dataframe

# %%
df1=pd.read_excel(r"D:\data1.xlsx",sheet_name="Feb")

# %%
df1
# Out:
#     Day    Product   Sales
# 0     1      cloths     98
# 1     2      cloths     56
# 2     3      cloths     43
# 3     4      cloths      5
# 4     5      cloths      6
# 5     6      cloths     87
# 6     7      cloths     34
# 7     8      cloths     25
# 8     9      cloths     34
# 9    10      cloths     26
# 10   11      cloths      3
# 11   12      cloths      4
# 12   13    Footware      7
# 13   14    Footware     56
# 14   15    Footware      2
# 15   16    Footware      1
# 16   17    Footware      5
# 17   18    Footware      7
# 18   19    Footware     65
# 19   20    Footware     24
# 20   21    Footware     56
# 21   22    Footware     98
# 22   23    Footware    101
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23

# %%
df_append=pd.concat([df,df1],axis=1)

# %%
df_append
# Out:
#     Day    Product   Sales   Day    Product   Sales
# 0     1      cloths     20   1.0      cloths   98.0
# 1     2      cloths     30   2.0      cloths   56.0
# 2     3      cloths      4   3.0      cloths   43.0
# 3     4      cloths     50   4.0      cloths    5.0
# 4     5      cloths     32   5.0      cloths    6.0
# 5     6      cloths     60   6.0      cloths   87.0
# 6     7      cloths     45   7.0      cloths   34.0
# 7     8      cloths     32   8.0      cloths   25.0
# 8     9      cloths     12   9.0      cloths   34.0
# 9    10      cloths     23  10.0      cloths   26.0
# 10   11      cloths     56  11.0      cloths    3.0
# 11   12      cloths     78  12.0      cloths    4.0
# 12   13    Footware     45  13.0    Footware    7.0
# 13   14    Footware     76  14.0    Footware   56.0
# 14   15    Footware      2  15.0    Footware    2.0
# 15   16    Footware     32  16.0    Footware    1.0
# 16   17    Footware     45  17.0    Footware    5.0
# ...

# %%
#Task: import excel "Jan" and "Mar"  sheets
#Merge two data frame by "day" and "product"#

# %%
df2=pd.read_excel(r"D:\data1.xlsx",sheet_name="Mar")

# %%
df2
# Out:
#     Day    Product   Sales
# 0     1      cloths     98
# 1     2      cloths     56
# 2     3      cloths     43
# 3     4      cloths      5
# 4     5      cloths      6
# 5     6      cloths     87
# 6     7      cloths     34
# 7     8      cloths     25
# 8     9      cloths     34
# 9    10      cloths     26
# 10   11      cloths      3
# 11   12      cloths      4
# 12   13    Footware      7
# 13   14    Footware     56
# 14   15    Footware      2
# 15   16    Footware      1
# 16   17    Footware      5
# 17   18    Footware      7
# 18   19    Footware     65
# 19   20    Footware     24
# 20   21    Footware     56
# 21   22    Footware     98
# 22   23    Footware    101
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23
# 28   29  Electronic     43
# 29   30  Electronic     54

# %%
df_merge=df.merge(df1,how="inner",on=["Day","Product "])

# %%
df_merge
# Out:
#     Day    Product   Sales_x  Sales_y
# 0     1      cloths       20       98
# 1     2      cloths       30       56
# 2     3      cloths        4       43
# 3     4      cloths       50        5
# 4     5      cloths       32        6
# 5     6      cloths       60       87
# 6     7      cloths       45       34
# 7     8      cloths       32       25
# 8     9      cloths       12       34
# 9    10      cloths       23       26
# 10   11      cloths       56        3
# 11   12      cloths       78        4
# 12   13    Footware       45        7
# 13   14    Footware       76       56
# 14   15    Footware        2        2
# 15   16    Footware       32        1
# 16   17    Footware       45        5
# 17   18    Footware       67        7
# 18   19    Footware       89       65
# 19   20    Footware       32       24
# 20   21    Footware        4       56
# 21   22    Footware        6       98
# 22   23    Footware        8      101
# 23   24  Electronic       98       23
# ...
