# %%
#Task1: import excel  "Feb" sheet file
import pandas as pd

# %%
import os
os.chdir(r"D:/")

# %%
df=pd.read_excel(r"D:\data1.xlsx",sheet_name="Feb")

# %%
df
# Out:
#     Day    Product   Sales
# 0     1      cloths     98
# 1     2      cloths     56
# 2     3      cloths     43
# 3     4      cloths      5
# 4     5      cloths      6
# 5     6      cloths     87
# 6     7      cloths     34
# 7     8      cloths     25
# 8     9      cloths     34
# 9    10      cloths     26
# 10   11      cloths      3
# 11   12      cloths      4
# 12   13    Footware      7
# 13   14    Footware     56
# 14   15    Footware      2
# 15   16    Footware      1
# 16   17    Footware      5
# 17   18    Footware      7
# 18   19    Footware     65
# 19   20    Footware     24
# 20   21    Footware     56
# 21   22    Footware     98
# 22   23    Footware    101
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23

# %%
#Task2 : Display basic checks

# %%
df.shape
# Out:
# (28, 3)

# %%
df.head()
# Out:
#    Day Product   Sales
# 0    1   cloths     98
# 1    2   cloths     56
# 2    3   cloths     43
# 3    4   cloths      5
# 4    5   cloths      6

# %%
df.tail()
# Out:
#     Day    Product   Sales
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23

# %%
df.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
df.dtypes
# Out:
# Day          int64
# Product     object
# Sales        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Day', 'Product ', 'Sales'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Day       28 non-null     int64
#  1   Product   28 non-null     object
#  2   Sales     28 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 800.0+ bytes

# %%
#Task3: a> Filter only cloths data and display

# %%
df_clo=df[df["Product "]=="cloths"]

# %%
df_clo
# Out:
#     Day Product   Sales
# 0     1   cloths     98
# 1     2   cloths     56
# 2     3   cloths     43
# 3     4   cloths      5
# 4     5   cloths      6
# 5     6   cloths     87
# 6     7   cloths     34
# 7     8   cloths     25
# 8     9   cloths     34
# 9    10   cloths     26
# 10   11   cloths      3
# 11   12   cloths      4

# %%
#		b> Filter only electronic data and display

# %%
df_ele=df[df["Product "]=="Electronic"]

# %%
df_ele
# Out:
#     Day    Product   Sales
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23

# %%
#		c> Filter only Foot ware data and display

# %%
df_foot=df[df["Product "]=="Footware"]

# %%
df_foot
# Out:
#     Day  Product   Sales
# 12   13  Footware      7
# 13   14  Footware     56
# 14   15  Footware      2
# 15   16  Footware      1
# 16   17  Footware      5
# 17   18  Footware      7
# 18   19  Footware     65
# 19   20  Footware     24
# 20   21  Footware     56
# 21   22  Footware     98
# 22   23  Footware    101

# %%
#		e> Filter cloths and electronic data & display

# %%
lst=["Electronic","cloths"]

# %%
df_ele_clo=df[df["Product "].isin(lst)]

# %%
df_ele_clo
# Out:
#     Day    Product   Sales
# 0     1      cloths     98
# 1     2      cloths     56
# 2     3      cloths     43
# 3     4      cloths      5
# 4     5      cloths      6
# 5     6      cloths     87
# 6     7      cloths     34
# 7     8      cloths     25
# 8     9      cloths     34
# 9    10      cloths     26
# 10   11      cloths      3
# 11   12      cloths      4
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23

# %%
#.Task4: import excel "Mar" and "Feb" excel sheets
#Append two dataframe

# %%
df2=pd.read_excel(r"D:\data1.xlsx",sheet_name="Mar")

# %%
df2
# Out:
#     Day    Product   Sales
# 0     1      cloths     98
# 1     2      cloths     56
# 2     3      cloths     43
# 3     4      cloths      5
# 4     5      cloths      6
# 5     6      cloths     87
# 6     7      cloths     34
# 7     8      cloths     25
# 8     9      cloths     34
# 9    10      cloths     26
# 10   11      cloths      3
# 11   12      cloths      4
# 12   13    Footware      7
# 13   14    Footware     56
# 14   15    Footware      2
# 15   16    Footware      1
# 16   17    Footware      5
# 17   18    Footware      7
# 18   19    Footware     65
# 19   20    Footware     24
# 20   21    Footware     56
# 21   22    Footware     98
# 22   23    Footware    101
# 23   24  Electronic     23
# 24   25  Electronic     45
# 25   26  Electronic      6
# 26   27  Electronic     34
# 27   28  Electronic     23
# 28   29  Electronic     43
# 29   30  Electronic     54

# %%
df_append=pd.concat([df,df2],axis=1)

# %%
df_append
# Out:
#      Day    Product   Sales  Day    Product   Sales
# 0    1.0      cloths   98.0    1      cloths     98
# 1    2.0      cloths   56.0    2      cloths     56
# 2    3.0      cloths   43.0    3      cloths     43
# 3    4.0      cloths    5.0    4      cloths      5
# 4    5.0      cloths    6.0    5      cloths      6
# 5    6.0      cloths   87.0    6      cloths     87
# 6    7.0      cloths   34.0    7      cloths     34
# 7    8.0      cloths   25.0    8      cloths     25
# 8    9.0      cloths   34.0    9      cloths     34
# 9   10.0      cloths   26.0   10      cloths     26
# 10  11.0      cloths    3.0   11      cloths      3
# 11  12.0      cloths    4.0   12      cloths      4
# 12  13.0    Footware    7.0   13    Footware      7
# 13  14.0    Footware   56.0   14    Footware     56
# 14  15.0    Footware    2.0   15    Footware      2
# 15  16.0    Footware    1.0   16    Footware      1
# 16  17.0    Footware    5.0   17    Footware      5
# ...

# %%
#Task: import excel "Feb" and "Mar"  sheets
#Merge two data frame by "day" and "product"

# %%
df_merge=df.merge(df2,how="left",on=["Day","Product "])

# %%
df_merge
# Out:
#     Day    Product   Sales_x  Sales_y
# 0     1      cloths       98       98
# 1     2      cloths       56       56
# 2     3      cloths       43       43
# 3     4      cloths        5        5
# 4     5      cloths        6        6
# 5     6      cloths       87       87
# 6     7      cloths       34       34
# 7     8      cloths       25       25
# 8     9      cloths       34       34
# 9    10      cloths       26       26
# 10   11      cloths        3        3
# 11   12      cloths        4        4
# 12   13    Footware        7        7
# 13   14    Footware       56       56
# 14   15    Footware        2        2
# 15   16    Footware        1        1
# 16   17    Footware        5        5
# 17   18    Footware        7        7
# 18   19    Footware       65       65
# 19   20    Footware       24       24
# 20   21    Footware       56       56
# 21   22    Footware       98       98
# 22   23    Footware      101      101
# 23   24  Electronic       23       23
# ...
